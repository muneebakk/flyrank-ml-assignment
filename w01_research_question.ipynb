# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/muneebakk/flyrank-ml-assignment/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# **Lane Chosen**: Content Refresh Queue Optimization.
# **Why**: I am choosing this lane because content decay and declining traffic are critical problems for any website. By optimizing which pages need a refresh first, we can save time and prioritize high-impact pages. The starter notebook already showed that a machine learning model can beat a simple hand-written rule by 3x on Precision@50, proving that data-driven ranking is highly valuable for this task.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# **Decision:** Which decaying or declining web pages should be assigned to content writers for a refresh or update this week?Action: Content managers will use the ranked queue to allocate writing budgets and tasks to update content, fix outdated links, or expand thin pages.
# **Cost of a wrong call**: False Positives (updating a stable page) waste expensive writing budgets and time on pages that do not need it. False Negatives (missing a truly declining page) lead to continuous traffic loss and drop in search rankings, costing the client organic revenue.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import os
import pandas as pd

possible_paths = [
    "data/raw/content_refresh_anonymized.csv",
    "../../data/raw/content_refresh_anonymized.csv",
    "../data/raw/content_refresh_anonymized.csv",
    "/content/flyrank-ml-internship-starter/data/raw/content_refresh_anonymized.csv"
]

df = None
for path in possible_paths:
    if os.path.exists(path):
        df = pd.read_csv(path)
        break

if df is not None:
    print(f"Total Pages Analyzed: {df.shape}")
    declining_count = (df["trend_direction"] == "down").sum()
    print(f"Declining Pages ('down' trend): {declining_count} ({declining_count/df.shape[0]*100:.1f}%)")
    median_impressions = df.groupby("trend_direction")["impressions_90d"].median()
    print("\nMedian Impressions by Trend Direction:")
    print(median_impressions.round(0).to_string())
else:
    print("Local data file path not found. Please verify your working directory.")
# Out:
# Local data file path not found. Please verify your working directory.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# **What I can claim:** This model serves strictly as a directional decision-support tool. It flags observed patterns of declining traffic based on historical search performance and helps managers prioritize their queue more efficiently than random choice.
# **What I CANNOT claim:** This work does not provide causal proof and does not 'predict Google's core algorithm changes'. It cannot guarantee that refreshing a flagged page will automatically restore lost rankings.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
